# %% [markdown]
# - 마크다운이란 개발자들이 좋아하는 언어의 표현 방식이다.
# - 공통된 문법으로 github, google colab, jupyter notebook, Notin 등 다양한 서비스에서 마크다운에 기반한 편집을 지원하고 있다.
# - 이를 잘 활용하면 편하게 깔끔한 문서를 만들 수 있다.

# %% [markdown]
# # 기본 문법

# %% [markdown]
# ## 제목 표현하기: `#`
# ### 제목 3
# #### 제목 4

# %% [markdown]
# ## 목록 표현하기: `- `, `1. `
# 뒤에 띄어쓰기 넣어줘야 함

# %% [markdown]
# - 순서없는 목록 1
# - 순서없는 목록 2
# - 순서없는 목록 3
#     - 순서없는 목록 들여쓰기 1
#
# 1. 순서 목록 1
# 2. 순서 목록 2

# %% [markdown]
# ## 글자 폰트: `*기울임*`, `**볼드**`, `~~취소선~~`

# %% [markdown]
# *기울임*
#
# **볼드체**
#
# ~~취소선~~

# %% [markdown]
# ## 코드 표현하기:

# %% [markdown]
# ```
# code block
# ```

# %% [markdown]
# inline code block: `code`

# %% [markdown]
# 코드는 `print()` 처럼 표시해줍니다

# %% [markdown]
# ## contents 삽입하기

# %% [markdown]
# [링크 제목](https://)
#
# ![이미지 제목](https://)

# %% [markdown]
# ## 인용 및 수식표시

# %% [markdown]
# > 인용표시는 `<` 로 합니다
#
# 수식은 $\sqrt{3x-1}+(1+x)^2.$

# %% [markdown]
# ## 기타사항
# ### 줄바꿈하기
# 줄 바꿈하려면 문장 끝 SPACE 3개 이상 넣어주거나 추가 줄바꿈을 해줘야 함
# 그래야 줄바꿈됩니다.
#
# 이렇게 하면 줄바꿈 안돼요
# 알겠죠?

# %% [markdown]
# # 기타 관련 툴

# %% [markdown]
# ## typora 툴 활용하기
# - 문서를 마크다운으로 쉽게 작성할 수 있는 툴
# - [다운로드 하기](https://typora.io/)
# - 환경설정 하기
# 아래 처럼 설정해줘야 이미지를 삽입했을 때
#     - 링크를 상대경로로 삽입해주고
#     - 이미지를 지정한 폴더에 자동으로 저장해줌
#     ![환경 설정](https://drive.google.com/uc?id=1sixKFpIUeYp9yKjgs1iX8Paa-Mjl5IfW)

# %% [markdown]
# ## notion-git 연동하기

# %% [markdown]
# https://github.com/uoneway/Notion-to-GitHub-Pages
